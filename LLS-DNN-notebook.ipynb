# %%
# !wget https://developer.download.nvidia.com/compute/cuda/12.4.0/local_installers/cuda_12.4.0_550.54.14_linux.run
# !chmod +x cuda_12.4.0_550.54.14_linux.run
# !sudo ./cuda_12.4.0_550.54.14_linux.run --silent --toolkit
# Out:
# --2025-11-03 16:26:03--  https://developer.download.nvidia.com/compute/cuda/12.4.0/local_installers/cuda_12.4.0_550.54.14_linux.run
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 23.46.17.43, 23.46.17.66
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|23.46.17.43|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4454353277 (4.1G) [application/octet-stream]
# Saving to: ‘cuda_12.4.0_550.54.14_linux.run’
#
# cuda_12.4.0_550.54. 100%[===================>]   4.15G   146MB/s    in 37s
#
# 2025-11-03 16:26:41 (114 MB/s) - ‘cuda_12.4.0_550.54.14_linux.run’ saved [4454353277/4454353277]

# %%
# !unzip LLS-DNN-main.zip
# !rm -r __MACOSX/
# !mv LLS-DNN-main LLS-DNN
# Out:
# Archive:  LLS-DNN-main.zip
#    creating: LLS-DNN-main/
#   inflating: __MACOSX/._LLS-DNN-main
#   inflating: LLS-DNN-main/.DS_Store
#   inflating: __MACOSX/LLS-DNN-main/._.DS_Store
#   inflating: LLS-DNN-main/requirements.txt
#   inflating: __MACOSX/LLS-DNN-main/._requirements.txt
#   inflating: LLS-DNN-main/script.sh
#   inflating: __MACOSX/LLS-DNN-main/._script.sh
#    creating: LLS-DNN-main/utils/
#   inflating: __MACOSX/LLS-DNN-main/._utils
#    creating: LLS-DNN-main/models/
#   inflating: __MACOSX/LLS-DNN-main/._models
#   inflating: LLS-DNN-main/main.py
#   inflating: __MACOSX/LLS-DNN-main/._main.py
#   inflating: LLS-DNN-main/utils/sgdschedulefree.py
#   inflating: __MACOSX/LLS-DNN-main/utils/._sgdschedulefree.py
#   inflating: LLS-DNN-main/utils/metrics.py
#   inflating: __MACOSX/LLS-DNN-main/utils/._metrics.py
#   inflating: LLS-DNN-main/utils/.DS_Store
#   inflating: __MACOSX/LLS-DNN-main/utils/._.DS_Store
#   inflating: LLS-DNN-main/utils/adamwschedulefree.py
# ...

# %%
# !cd LLS-DNN/; pip install torch==2.2.1 torchvision==0.17.1 torchaudio==2.2.1 --index-url https://download.pytorch.org/whl/cu118
# !cd LLS-DNN/; pip install numpy
# !cd LLS-DNN/; sed -i '/numpy/d' requirements.txt
# !cd LLS-DNN/; sed -i '/torch/d' requirements.txt
# !cd LLS-DNN/; sed -i '/torchvision/d' requirements.txt
# !cd LLS-DNN/; pip install -r requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 819.1/819.1 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.2/6.2 MB 85.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 109.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 110.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 66.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 130.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 728.5/728.5 MB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 6.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 7.5 MB/s eta 0:00:00
# ...

# %%
# !cd LLS-DNN/; python main.py --dataset CIFAR10 --model LLS_SmallConv --num-epochs 25 --lr 0.01 --training-mode LLS --waveform cosine --batch-size 128 --test-batch-size 128 --optimizer Adam
# Out:
# Namespace(save_path='./experiments/LLS_SmallConv_CIFAR10_LLS_Adam_42746', dataset='CIFAR10', dataset_dir='~/Datasets', model='LLS_SmallConv', num_epochs=25, lr=0.01, training_mode='LLS', waveform='cosine', batch_size=128, test_batch_size=128, weight_decay=0, momentum=0.9, pool='MAX', optimizer='Adam', milestone=[50, 80, 120, 180], gamma=0.3, print_freq=300, experiment_name='LLS', lr_scheduler='ReduceLROnPlateau', save_best_model=False, classes_per_batch=None, patience=1000, temperature=0.5, label_smoothing=0.0, dropout=0.0, record_gpu_mem=False)
# => Everything will be saved to ./experiments/LLS_SmallConv_CIFAR10_LLS_Adam_42746
# ...
# 100% 170498071/170498071 [00:06<00:00, 25855622.04it/s]
# Extracting /root/Datasets/cifar-10-python.tar.gz to /root/Datasets
# Files already downloaded and verified
# Files already downloaded and verified
# ...

# %%
# !nsys profile --force-overwrite true --gpu-metrics-device=all -o lls_dnn_profile bash -c "cd LLS-DNN/ && python main.py --dataset CIFAR10 --model LLS_SmallConv --num-epochs 2 --lr 0.01 --training-mode LLS --waveform cosine --batch-size 128 --test-batch-size 128 --optimizer Adam"
# Out:
# GPU 0: General Metrics for NVIDIA TU10x (any frequency)
# /usr/local/lib/python3.12/dist-packages/torch/optim/lr_scheduler.py:28: UserWarning: The verbose parameter is deprecated. Please use get_last_lr() to access the learning rate.
#   warnings.warn("The verbose parameter is deprecated. Please use get_last_lr() "
# Namespace(save_path='./experiments/LLS_SmallConv_CIFAR10_LLS_Adam_74274', dataset='CIFAR10', dataset_dir='~/Datasets', model='LLS_SmallConv', num_epochs=2, lr=0.01, training_mode='LLS', waveform='cosine', batch_size=128, test_batch_size=128, weight_decay=0, momentum=0.9, pool='MAX', optimizer='Adam', milestone=[50, 80, 120, 180], gamma=0.3, print_freq=300, experiment_name='LLS', lr_scheduler='ReduceLROnPlateau', save_best_model=False, classes_per_batch=None, patience=1000, temperature=0.5, label_smoothing=0.0, dropout=0.0, record_gpu_mem=False)
# => Everything will be saved to ./experiments/LLS_SmallConv_CIFAR10_LLS_Adam_74274
# Files already downloaded and verified
# ...
